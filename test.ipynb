# %%
import cv2
from tracker import BasketballTracker, PoseTracker
from AI_referee import AIReferee

# %%
cap = cv2.VideoCapture("data/video/perpendicular_angle.mov")  # or video path
ref = AIReferee(BasketballTracker(), PoseTracker())

while True:
    ok, frame = cap.read()
    if not ok:
        break

    annotated, meta = ref.infer_frame(frame, bb_conf=0.25, pose_conf=0.25)

    # 顯示事件
    for ev in meta['events']:
        print(ev)

    cv2.imshow("AI Referee", annotated)
    if cv2.waitKey(1) & 0xFF == 27:  # ESC
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 if not ok:
#       7     break
# ----> 9 annotated, meta = ref.infer_frame(frame, bb_conf=0.25, pose_conf=0.25)
#      11 # 顯示事件
#      12 for ev in meta['events']:
#
# File ~/Documents/Program/basketball_project/AI_referee/referee.py:189, in AIReferee.infer_frame(self, frame, bb_conf, pose_conf)
#     187 self.frame_index += 1
#     188 # Step 1: bounding-box tracker (YOLO + ByteTrack-like association)
# --> 189 bb_annot, bb_meta = self.bb_tracker.infer_frame(frame, conf=bb_conf)
#     190 persons = bb_meta['tracks'].get('person', [])
#     191 balls = bb_meta['tracks'].get('sports ball', [])
#
# File ~/Documents/Program/basketball_project/tracker/basketballTracker.py:201, in BasketballTracker.infer_frame(self, frame, conf)
#     199 t0 = time.time()
# ...
